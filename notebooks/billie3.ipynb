# %%
import numpy as np
import pandas as pd
import random
import sys

import tensorflow
import keras

from keras import layers
# Out:
# /Users/mattmastin/opt/anaconda3/envs/billie-env/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/mattmastin/opt/anaconda3/envs/billie-env/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/mattmastin/opt/anaconda3/envs/billie-env/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/mattmastin/opt/anaconda3/envs/billie-env/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/mattmastin/opt/anaconda3/envs/billie-env/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/mattmastin/opt/anaconda3/envs/billie-env/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
# Stochastic Sampling: introducing randomness into the generative process

# Temperature range: 0.01 - 1.0
# Higher temp result in higher entropy sampling distributions = more surprising and unstructured
# Lower temp result in less randomness and more predictable generated text

def reweight_distribution(original_distribution, temperature=0.5):
    distribution = np.log(original_distribution) / temperature
    distribution = np.exp(distribution)
    
    return distribution / np.sum(distribution)

# %%
text = (open('lyrics_aggregated.txt').read().lower())
print(f'Corpus length: {len(text)}')
# Out:
# Corpus length: 49563

# %%
# %%time
# Vectorizing sequences of characters

maxlen = 60
step = 3
sentences = []
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
    
print(f'Number of sequences: {len(sentences)}')

chars = sorted(list(set(text)))
print(f'Unique chracters: {len(chars)}')
char_indices = dict((char, chars.index(char)) for char in chars)

print('Vectorization...')

x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 16501
# Unique chracters: 57
# Vectorization...
# CPU times: user 323 ms, sys: 26.2 ms, total: 349 ms
# Wall time: 368 ms

# %%
# Small baseline model

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# WARNING:tensorflow:From /Users/mattmastin/opt/anaconda3/envs/billie-env/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# Reweighting the original probability distribution returned from model and draw a character from it

def sample(preds, temperature=0.5):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
# %%time
# Training and generating text

for epoch in range(1, 60):
    print(f'epoch {epoch}')
    model.fit(x, y, batch_size=128, epochs=1)
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')
    
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print(f'------ temperature: {temperature}')
        sys.stdout.write(generated_text)
        
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1
                
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            
            generated_text += next_char
            generated_text = generated_text[1:]
            
            sys.stdout.write(next_char)
# Out:
# epoch 1
# Epoch 1/1
# 16501/16501 [==============================] - 55s 3ms/step - loss: 1.9068
# --- Generating with seed: "  "you can whip your porsche",
#             "i been in the va"
# ------ temperature: 0.2
#   "you can whip your porsche",
#             "i been in the vars in that in the ine thit the wind the thit in thit ine thin the thit in that the whing thing the care the wind in thit in the wind in thit ind thit ing thi thithing that ind in in thit thing the will thin't in that ind thin the ming the thit ing thin thing the thit the bill thind in ine that ind the thit ind thand thin the will the that ine thind in in the wirle thit ind thit ind in thind thing ------ temperature: 0.5
#  ine thind in in the wirle thit ind thit ind in thind thing thill the hame it ine hin youthi thinl is burte",
#                "don on b and lilit tring thind sillithics itlild mad ars don iili don taad int and ive tore that inigi biee the yourin thine yor b ind the miche bure inin ing",
#                    "in't no onicame thind ing mind bul trad thi tort the lithe ine thare thind you ninn wall wari goridin",
#                      "ing thi winl bhe gout arics------ temperature: 1.0
#  goridin",
#                      "ing thi winl bhe gout arics –belyg",
#                "stirl tatad owhibigo caili mit me iiet"d\  { "galp yoaigh w(wind",
#                   "and at orelg\bar",
#                 "an, yreise  nicewe thaikay",
#                 ",rbtibnd",
#                 "[vitfeig
#  \h]",
#       ]          "[ving",
#                "",
#                "pcee guyay whathabloutg e n geav yooth",
#                 "thiwe",
#                "anligs – va, aud in------ temperature: 1.2
#                 "thiwe",
#                "anligs – va, aud inriree ,
#         cabhev idthiwunt iyd",
#        "i [o[cngpvii co{yathing",
#              "letlip[oevo
# no'kewe gim uyce]",
#                    "ant tithi, "oustte",
#                 y –he ami avuurislidn (ian",
#               htswiccand  ilyoge,"bvrvet.iga",
#           " ihari,plapy ball sre,tlopthat bnireu dhan a da e hhrusenlrang lalreet's bconj",                 "",
#                  w",
# b   fe    "frldepoch 2
# Epoch 1/1
# 16501/16501 [==============================] - 50s 3ms/step - loss: 1.4572
# --- Generating with seed: ""i'm that bad type",
#             "make your mama sad type",
# "
# ------ temperature: 0.2
# "i'm that bad type",
#             "make your mama sad type",
#             "in the like the her the whe whor the whe on the wher the oo the hor the whor the a dour my her the hor don the horus]",
#               "[verse 1]",
#               "sut the like i a whe hour a burt the hor done the her in the hor the whe ming the hour don the hire the hour and a my her don the whit the hour dond the her don the her in the har in the whe hor dann the a like the my hike i ------ temperature: 0.5
# her in the har in the whe hor dann the a like the my hike i a the buy bur for light ding the i hou on the a rous the the to are my hor",
#             "the  i        "sot when but shing the stare a bur thit the the worus but her an the on the i like ou an hor cor chor purounge my hor",
#               "but the i hine i hor burt",
#             "i my hars the dound whon my hire my hor con",
#             "then i whe wor a bear the sourt thand in wor your an my hike------ temperature: 1.0
# then i whe wor a bear the sourt thand in wor your an my hiken the mik nith, i beridt the a mid s and my wide ",
#   u         "",
#             "shm hion",               "up mo the nonken rorenn ne",
#             "i wife srur, in aken'r he m nike ly ho-",
#              "",
#             "in te bret",
#         "witkm aniy us sue, thin'the strikmy",
#             "you illh tot nics uelmy hele",
#               "d golmang burg",
#             "con",
#         "thar mus",
#     ------ temperature: 1.2
# d golmang burg",
#             "con",
#         "thar mus",
#           "[vert m| )cucrepom ]ige hovuy whe o auke ]y divid' (ous 3ebus doundy j ill thing in't like lur, himin'm",
#   p         "told carayolrmy",
#             "jut'y to",
#           "o w's whi",
#             "an an the noub me wy yyurpisunia mayly",
#           "[virs t!",
#           mums i my for, camy my \siftlemibengiac, lor gove slian, eurica 5aan, scthit, 'son't ml yournlukny hur, liketn hike {
# ":]",epoch 3
# Epoch 1/1
# 16501/16501 [==============================] - 52s 3ms/step - loss: 1.2591
# --- Generating with seed: "d lie, say i like it like that, like it like that",
#         "
# ------ temperature: 0.2
# d lie, say i like it like that, like it like that",
#             "be the didn't start the day the wind the will the forld the forld the paiding",
#             "but the gind i'm the bad in the wind",
#             "be the bidning",
#             "sterse the dinnit the dourt the dond",
#             "sher i dinnit thit the cand",
#             "but the winning the dond",
#             "she bad ding",
#             "be the dinnit the dind",
#             "but the fire the ba------ temperature: 0.5
#   "be the dinnit the dind",
#             "but the fire the bad dight is like i start that",
#             "then i dinge thot shin't start the fourd",
#             "but i mike the blaws tond",
#             "[chorus gorlim the binger belny start the fornd",
#             "",
#             "in withe the wind in the might",
#           "you cand da ding to fill your giin",
#             "start the gind like i bar thithis seaty thithing",
#             "been but to me dong",
# ------ temperature: 1.0
# thithis seaty thithing",
#             "been but to me dong",
#             "
#     "and pandy whan'a ca youm",
#             "",
#             "say ow the dight oli fayring rous",
#             "n thit on wing, ferla start yourde stols reap ut in the farn, wmat, dand",
#             "[verse 1]",
#             "peenin't solly siadwond",
#             "a dret gindis qogh",
#             "jut onru f i whries ginp",
#             "sner in ay i'll be nea the carmititly bo kndas kne------ temperature: 1.2
#          "sner in ay i'll be nea the carmititly bo kndas kney",
#             "ickhthi ooknnd], dou bancell bre la thiil wh res ois thabne",
#           "memy wten you",
#           [
#     "[pundgwey dand",
#             "lekin't be",
#             "thitrlidin't gaimy n  chit i'm qtand like i pey hiec",
#             "whet sty kidly vickeys tothics"
#  r       "my i’ oo hey sondt, dond",
#     f       "udd[chand ",
#             "ald lyroldn crast",
#            "bveke stars tepoch 4
# Epoch 1/1
# 16501/16501 [==============================] - 53s 3ms/step - loss: 1.1149
# --- Generating with seed: ",
#             "spread the ear pollution both far and wide",
# "
# ------ temperature: 0.2
# ,
#             "spread the ear pollution both far and wide",
#             "stall the and bees the hirs the will me and my heart you gon the world",
#             "[verse 1]",
#             "sound but it's a way her in the whe when's been the hive",
#             "i'm the nown we lin't the whe whe well my heart to ponnin' in't wet one",
#             "i'm not it whe owe to lite it a whate the will me heart to your anes in the world",
#             "",
#             "[ver------ temperature: 0.5
# o your anes in the world",
#             "",
#             "[verse 1]",
#             "but the pays when buy i can't nevin'  her cone",
#             "say hart whan she har in't start the live",
#             "[verse 1]",
#             "lake i'm nown the wars",
#             "i'm nothin't stars my heart the werle",
#             "so can't the wike it like that shen wall the fire",
#             "i'm got i mavice bean the will ma heart my hearte",
#             "whin's bad in'------ temperature: 1.0
# an the will ma heart my hearte",
#             "whin's bad in's the crice",
#             "and puad goot\ slele you",
#             "sooptale my heart been ?",
#             )"i love gar ond heal we plieker thes mow",
#             "",
#             "[verse 1]",
#             "butwers you buet the enawe the pous is her mowh",
#             "as tke it's babevy",
#             "",
#               "i cake a and her it
# the lit my brit, abce ou ce cellike sead the enebke",
#        ------ temperature: 1.2
# he lit my brit, abce ou ce cellike sead the enebke",
#             "hey ",
#             ] "he's lowmy hams",
#             "dyeveuse way us eh",
#               "a an",
#             "mnd",
#             "thy our a steen ac pranses",
#             "[verse i]",
#             "[verseo]",
#             "ma'ks hean it-ham",
#             "a laken creaty whtliwe",
#             "soreu",
#             "not but yeab ceveris like't start my (layes breald norey",
#             "s u dine ouepoch 5
# Epoch 1/1
# 16501/16501 [==============================] - 50s 3ms/step - loss: 0.9855
# --- Generating with seed: "m here for",
#             "i'm built for having a ball",
#     "
# ------ temperature: 0.2
# m here for",
#             "i'm built for having a ball",
#             "i'm gonna sinn the world",
#             "she's been and and and and don't now",
#             "she's been and in a the one my horld",
#             "she's boen the stall the world",
#             "and the know the horld",
#             "i'm gonna the horld",
#             "she's boen and in a the horld",
#             "",
#             "[bre-chorld and and we porld",
#             "she's boen and and and ------ temperature: 0.5
# orld and and we porld",
#             "she's boen and and and be the dond it llick that so the drot me her",
#             "and i sond been in ling",
#             "",
#             "she's bole and and the rorld",
#             "",
#             "[verse 1]",
#             "she's a bign thas onl",
#             "",
#             "[bre-bes harling and and the gorld's be lore the frouse don't the wirld",
#             "",
#             "[verse 1]",
#             "",
#             "[ch------ temperature: 1.0
# ",
#             "[verse 1]",
#             "",
#             "[chrrurge realing yire",
#             "shers has pay in no haorman",
#             "and snelr don't evert sabwn world grod eret, cakem ir coon",
#             "in a marlsf, warkit t us gore",
#             "beerli gool, be tllekcr",
#             "all ele that all deuso cor don's belly wearqu\",
#             "as onlg\",
#               "fort goad, she und like",
#             "seepshert alwy kn mel, he gawd",
#     ------ temperature: 1.2
# nd like",
#             "seepshert alwy kn mel, he gawd",
#             "you jaas, behnelwe we paad ty",
#           )"ma ip you jasler the rnind",
#             foll virg , strake",
#             "ylerret, dieayo my hurhhtr",
#             "chi'ml ovan enk gone, "rings and youngeo munde",
#             "ust at ay hor vyrus",
#             "mh ot a dblaterl",
#             "st ppa thi gni'm not het in  hike",
#             "bake bay her knlas h",
#             "[,  buend go pouepoch 6
# Epoch 1/1
# 16501/16501 [==============================] - 51s 3ms/step - loss: 0.8802
# --- Generating with seed: "n eyes",
#             "",
#             "[chorus]",
#            "
# ------ temperature: 0.2
# n eyes",
#             "",
#             "[chorus]",
#             "stees the ki't like the fire",
#             "but ma heart and all the world",
#             "stood the didn't stars",
#             "stees the saided all my heart",
#             "i'm the ki't like the ollys to the world",
#             "but ma heart and i lang the one",
#             "stees to sunner the world",
#             "",
#             "[verse 1]",
#             "stors the fire",
#             "i'm the da------ temperature: 0.5
# e 1]",
#             "stors the fire",
#             "i'm the dayd is nothin' a bake",
#             "it she paad ton good",
#             "i'm the king be notring you reall",
#             "we didn't stars",
#             "and it so bady and guy",
#             "but ma can't night we do don't littmin' crong",
#             "i'm the dain't the one",
#             "stees the kigh be the don't ster, told to the one",
#             "steoke me, baby)",
#             "only the ma on------ temperature: 1.0
#
#             "steoke me, baby)",
#             "only the ma oneis rat, to bad"
#         ],
#       ],
#       ],
#       : t t "st ould in grees youngir"ss tad in my bety trotkeritr spome stare",
#             ",
#             "then whe's enastan,  o likn i shut ii hee-hies"",
#               "",
#             "only tole my heve mon)",
#            o"the resey sundangery",
#             "blls i a high giys tom no tyou"i's bree",
#             "dout h my werd it's sheness tousto,------ temperature: 1.2
# "i's bree",
#             "dout h my werd it's sheness tousto, so hee-[eehe eneven nown, stuoker fremt the ramn of sonts to the ot(one bealy tomegor, the howe",
#             "down thie's the fire",
#             "ghe li| guvt light de",
#             "nev ese her care i]",
#             "ir a figstur,, bubphaw,  abley sayt yoe",
#             "dald my hies knmo kald my you",
#             saeesell say
#  ] ake my her cracc",
#             "",
#             "",
#             "epoch 7
# Epoch 1/1
# 16501/16501 [==============================] - 52s 3ms/step - loss: 0.7869
# --- Generating with seed: " like a stone",
#             "with the headlights pointed at "
# ------ temperature: 0.2
#  like a stone",
#             "with the headlights pointed at the world's been then ing on",
#             "she'll good die my weart",
#             "she'll suidan' firling you the world's been that, wat old to what one",
#             "she'll we didn't start the fire",
#             "she'll good die your cand i mone",
#             "i'm gonna ride 'til i can't no more",
#             "i'm been whin whit whit wo line",
#             "she'll good died the world's been then------ temperature: 0.5
# o line",
#             "she'll good died the world's been then she your dander that ollys crut",
#             "se puin't nowhy ulwight on my flows",
#             "she'll be buling in the ran, i blasser, the drinking on the fored's been",
#             "he gidn't start the wirlin s a bable my with the weado now on",
#             "but i know the good die young",
#             "but i good die my whing the wirl",
#             "and i give this not my lover",
#             ------ temperature: 1.0
# l",
#             "and i give this not my lover",
#             "id'illy",
#             "you gednia sto cance you got we did'od wet hour orlanes",
#             "hey littlevs civi s an in eres, day to but",
#             "we tidn't stars",
#             "no, what yourguno, stearen's navin' that and withxi'm non \",
#             "kiel net sust rown",
#             " ond we cin't never uonang (hen'ight",
#             "ware housge",
#             "than you cad noll in this wo------ temperature: 1.2
#     "ware housge",
#             "than you cad noll in this world cougd sougi lone",
#             "you cancald my, make dire \"s\"tha           "slokpe's gond end now",
#             "lawmy can to head old tot",
#             "he reapthy prest who",
#             "a oh(u? puit\ fill youn caw",
#             "sverle souy us a woad",
#             "sheps\ poud tye",
#             "shille puas]",
#             "i'mastarke rer spepp andver gumth",
#             "yescurcathefliinepoch 8
# Epoch 1/1
# 16501/16501 [==============================] - 58s 4ms/step - loss: 0.7043
# --- Generating with seed: "hat kind of guy i've been",
#             "and then i'll win","
# ------ temperature: 0.2
# hat kind of guy i've been",
#             "and then i'll win",
#             "you can tell my heart the for a boble and and at you well my heart the flowe",
#             "i'm the wall you can the froum or a babling you for a bee",
#             "i'm tonely the dood do mone",
#             "i lon't tell your from come one",
#             "i'm the wall you well my heart the froamy in the dood you  one",
#             "i lon't start the froe sonnis that i men like that",
# ------ temperature: 0.5
#       "i lon't start the froe sonnis that i men like that",
#             "we didn't start the froume of could the world's beenothy",
#             "she'll onea me whone",
#             "and wall the day to fortan, this world",
#             "i'm the godd to whin a the's by blowd at the radin'",
#             "she'll be tole your oneall",
#             "she'll beer ir not my with the when ore",
#             "then i wait sut the well my heart, you the well you gone",
#   ------ temperature: 1.0
# hen i wait sut the well my heart, you the well you gone",
#             "you're a bidneve",
#               "betwonear in sold by like that, purtart aur puy mo forting",
#             "",
#             "[verse 2]",
#             "in to ear ay it all chof co pivort gut",
#             "",
#             "[etpocen\",
#             "undore the burf on the dreal",
#             "she'll been in  i gom's bees tolf thp forld",
#             "he a'm no, hableronot",
#             "she'l------ temperature: 1.2
# ld",
#             "he a'm no, hableronot",
#             "she'll stali poame brot so the dleyorse talk",
#             "hen bree and alwort me cone pomp on a bow",
#             "younge",
#             "i’d olly heves eurengly",
#             "but is frurfink cabe",
#             "your frouie the weil",
#             "[chorus]",
#             "thy saytet, don't starce ttar vigh"y"
# ) i f w le ie, don't me nowrse",
#             "sfer iigodack fony febm",
#     b       "wat rothepoch 9
# Epoch 1/1
# 16501/16501 [==============================] - 57s 3ms/step - loss: 0.6407
# --- Generating with seed: "ie jean is not my lover",
#             "she's just a girl who"
# ------ temperature: 0.2
# ie jean is not my lover",
#             "she's just a girl whou sood",
#             "",
#             "[verse 1]",
#             "",
#             "[verse 1]",
#             "",
#             "[verse 1]",
#             "",
#             "[verse 2]",
#             "",
#             "[verse 1]",
#             "",
#             "[verse 3]",
#             "",
#             "[verse 1]",
#             "",
#             "[verse 1]",
#             "",
#             "[verse 1]",
#             "",
#       ------ temperature: 0.5
#          "",
#             "[verse 1]",
#             "",
#             "[chorus]",
#             "we didn't start the wirld good it this oreake tound",
#             "",
#             "[verse 1]",
#             "",
#             "[verse 1]",
#             "i was head in thi know this me one",
#             "i lould don't ean",
#             "on you kine dream warn",
#             "stroke me, nthe goon, da da lack,         "in on the doon ding the wood",
#             "i wam hey br------ temperature: 1.0
#    "in on the doon ding the wood",
#             "i wam hey breakius a thate",
#             "i 'roung treys hoom ore",
#             "\"i'm bread senn, gut't se the don't now joonith thit mane",
#             "",
#             "[verse 1]",
#             "she'll groubbe it you can thie!,            "i son stownearn whin  good dien",
#             "i'm to whink die ma tous what's the wood",
#             "and we fire and bubougdsicr phat we like me thime",
#             "a t------ temperature: 1.2
# ire and bubougdsicr phat we like me thime",
#             "a thi't line, was old leam be aighy ur own",
#            "",
#             "[verse 2]",
#             "hun ohe good pold, you me",
#             "hard fove jasn what springs trieking wior sturpore",
#             ""corus]",
#             ",
#           "[verse 2]",
#             "[chorus]",
#             "at and con'r h blwy cineed tow froo mo aid to",
#             "soh, just areforears \",
#             "",
#            epoch 10
# Epoch 1/1
# 16501/16501 [==============================] - 58s 3ms/step - loss: 0.5837
# --- Generating with seed: "   "headlines, deadlines jamming your mind",
#             "yo"
# ------ temperature: 0.2
#    "headlines, deadlines jamming your mind",
#             "you can the stre go figg",
#             "but the know this hor s",
#             "but i 'rid got and town road",
#             "i'm gon't be a singe like i , bur a maghin's day i like i lles",
#             "i'm gon't be the good die youn sinte the world",
#             "but i 'right it, but whet you do lough sintt ne, maby heart",
#             "",
#             "[verse 1]",
#             "she's like i , baby hea------ temperature: 0.5
#            "[verse 1]",
#             "she's like i , baby hearle, carse whin",
#             "but the knet the old town road",
#             "i'm gon't be the good",
#             "the sall thas go like i lofe",
#             "",
#             "[chorus]",
#             "make your danct it your diele this horld",
#             "",
#             "[chorus]",
#             "the shike i lan ly ill this whiter from no who",
#             "[verse d]",
#             "i'm ging i spuld no------ temperature: 1.0
# ",
#             "[verse d]",
#             "i'm ging i spuld now",
#             "",
#             "[peste-bring since rears rpynun",
#             "bde groussos goodbdg",
#             "iely when you will dance i poad",
#             "so you're a nid yours ty cin wim for and tre gung",
#             "le an on yourse to fight in",
#             "statpore puse now mef hond",
#             "she's are a fon's like in thi digmy (omh",
#             "of can men ene you"lyliind your------ temperature: 1.2
# hi digmy (omh",
#             "of can men ene you"lyliind your xorleys the olown-",
#             "[vers got bread her pray",
#             "dnows reacs",
#             "ffor i raunibes knet the waid",
#             "bay guysnight, ret maves what ur fow in's stees rpatty widlis, than mom ri: youi veald cems",
#             "don't got's bet're ius lightss it you me nieg dr (s",
#             "and witholights aid juse no, whare",
#             "nownight start the pealits anepoch 11
# Epoch 1/1
# 16501/16501 [==============================] - 52s 3ms/step - loss: 0.5443
# --- Generating with seed: "",
#             "",
#             "[verse 4]",
#             "it'"
# ------ temperature: 0.2
# ",
#             "",
#             "[verse 4]",
#             "it's a aid ton the world's been turning the round",
#             "",
#             "[pre-chorus]",
#             "",
#             "[pre-chorus]",
#             "she'll grow the did on the for you wor the from the world's been turning",
#             "i lound now i'm neart and and now the round",
#             "",
#             "[pre-chorus]",
#             "",
#             "[chorus]",
#             "",
#             "[ch------ temperature: 0.5
# "",
#             "[chorus]",
#             "",
#             "[chorus]",
#             "then shey stale my firt the wich",
#             "",
#             "[pre-chorus]",
#             "stroke mo, stroke me, breach got i for a feav",
#             "",
#             "[chorus]",
#             "there i and it white on the will you",
#             "but i wall the fire",
#             "then i heal the paithe the world's gonnthin't the form",
#             "she'll grow i'm not it like t------ temperature: 1.0
# thin't the form",
#             "she'll grow i'm not it like thit, willim hits reyting hive go",
#             "that whice gonn, nt)rustre and goom",
#             "i just dan't nobody glow",
#             "",
#               "[.horus]",
#             "flike my have thel styokin't liup a makes ellulino horeen",
#             "it's got cale in whit i'm no the plowngey munt",
#             "",
#             "[pre-is -oppare a say",
#             "",
#             "[chorus]",
#     ------ temperature: 1.2
# -oppare a say",
#             "",
#             "[chorus]",
#             "lewrand in the dim qupen'th howe whalkec",
#             "",
#             "[prercat onever here wht's sooh me end",
#             "whin't cang young like me loncer",
#             "sty i will your i kno, ronng mine",
#             "for thered are ie irun efe writh a", bieley",
#             "to in is , no't gey",
#             "we dolls gonnin? route for my with bront",
#             "then 'cknowring i epoch 12
# Epoch 1/1
# 16501/16501 [==============================] - 52s 3ms/step - loss: 0.5102
# --- Generating with seed: "s feeling alright"
#         ]
#     ],
#     "title": "billy joel"
# ------ temperature: 0.2
# s feeling alright"
#         ]
#     ],
#     "title": "billy joellie jurevin in  has good don like wo prite",
#             "so hat heve your for yougr do lown",
#             "i'm the bad es end it a whise no good don's gong",
#             "sout the bad eyes",
#             "",
#             "[pre-chorus]",
#             "i'm the bad es end it a whous a whes i'me the pood don't no more",
#             "",
#             "[pre-chorus]",
#             "",
#             "[pre-chorus------ temperature: 0.5
#     "[pre-chorus]",
#             "",
#             "[pre-chorus]",
#             "i'm the bad eyes",
#             "i'm the bad eyes, f r the payes cone",
#             "but is got a light it your one my is to felling you like the rounde the prime",
#             "",
#             "[chorus]",
#             "sout when she well yourlifort a soon",
#             "sond it when she wall you love to the one",
#             "she'll prealino good don't got to esty fill",
#            ------ temperature: 1.0
#   "she'll prealino good don't got to esty fill",
#             "thise span you reamin' has hovide a conl",
#             "i gound to whin' hes miniding fort",
#             "you've nove you a breans\",
#             "con't toke mo a reserpespee, wall me now, you geen's teady past",
#             "lo, me ovey day to start the rain, b is hor rnow",
#             "fillin' jean is nooh",
#             "hey onead and told is now toupa we",
#             "bellight call me, stra------ temperature: 1.2
# d told is now toupa we",
#             "bellight call me, strange and live it acamy to fill"gut cantirg",
#             "mjearle sturnmy sicking ted in ,
#             "and to don't no-no, hor lifina hibling with wi'l",
#             "you kid[
#           "she'll onea\",
#             "vicke that i your cofe",
#             "ancele on my blackurood",
#             "bedres onosha caet it hive you lovering you rown life a five",
#             "i you gill che ba)",
#            epoch 13
# Epoch 1/1
# 16501/16501 [==============================] - 53s 3ms/step - loss: 0.4824
# --- Generating with seed: "       "you're so together, boy",
#             "stroke me, st"
# ------ temperature: 0.2
#        "you're so together, boy",
#             "stroke me, stroke me, strees ennt in think will the horse the old toore",
#             "that's whe one me, hight ur of bood",
#             "i'm gonna tall my all awh for a rean",
#             "and i knet the one",
#             "that's whe one me, breake and and all the world",
#             "and i house whote oneam or all the world's been turning",
#             "i'm gonna stall crow",
#             "i'm gonna tall my h------ temperature: 0.5
#     "i'm gonna stall crow",
#             "i'm gonna tall my heart",
#             "that a kive the old tooreake the world",
#             "and you're now me hor dall",
#             "and when i'm sinner can",
#             "and he's really like to hightring think dimp that i'm head to plawn",
#             "and pealwell like thit shide that's figgongridg, liteli o",
#             "she's no heavy gloss how",
#             "that's whe one your she ene",
#             "that s------ temperature: 1.0
#           "that's whe one your she ene",
#             "that stin't now the nowm",
#             "that wo is he daid, your ghone",
#             "and you'te firt",
#             "ar",
#             "loree, stse heart, ppaytarn't tell my forok, bibaes at lan",
#             "the stals micake nowh, woradatar",
#             "lit licathe have oway",
#             "i'm no wean you reaw",
#             "frantht, dallina michi''tad i'm freak",
#             "",
#             "",
#     ------ temperature: 1.2
#  michi''tad i'm freak",
#             "",
#             "",
#             "i'm nearus]",
#             "and es",
#             "i've neve she's lovern ame",
#             "chen the good die young",
#             "he kinguredan, yell",
#             "and you''men as then't not seitr caires",
#             "",
#             "[chorus]",
#             "and im ocay those o'm no ro]",
#             "",
#             "odlcho, cango",
#             "justing ouwning",
#             "so ,toode kepoch 14
# Epoch 1/1
# 16501/16501 [==============================] - 65s 4ms/step - loss: 0.4517
# --- Generating with seed: "at shine",
#             "and warm the lovers’ glass",
#        "
# ------ temperature: 0.2
# at shine",
#             "and warm the lovers’ glass",
#             "",
#             "[chorus]",
#             "",
#             "[chorus]",
#             "",
#             "[chorus]",
#             "",
#             "[chorus]",
#             "",
#             "[chorus]",
#             "",
#             "[chorus]",
#             "",
#             "[chorus]",
#             "",
#             "[chorus]",
#             "",
#             "[chorus]",
#             "",
#             "[chorus]",
#        ------ temperature: 0.5
#  "[chorus]",
#             "",
#             "[chorus]",
#             "",
#             "[chorus]",
#             "",
#             "[chorus]",
#             "",
#             "[verse 1]",
#             "steeling fire",
#             "but stalics goodb bid you",
#             "now care",
#             "it's a pay her poy",
#             "",
#             "[chorus]",
#             "",
#             "[chorus]",
#             "we didn't start the good die young",
#             "",
#             ------ temperature: 1.0
# dn't start the good die young",
#             "",
#             "[pro-cholling onethes we reed own like no hmautg",
#             "seep one",
#             "when she seep ooreas",
#             "howle sood, your don't now toody se whome plown me, wa",
#             "weart ing upawack",
#             "hey'r don't never heuld your plife you",
#             "",
#             "[pre-chorus]",
#             "fill the racs onet the prime me crife",
#             "you getall litisten, ------ temperature: 1.2
# onet the prime me crife",
#             "you getall litisten, you thingsten sice",
#             "",
#             "[chorus]",
#             "all all ta know",
#             "we do dancang onefor higg",
#             "i'm ing",
#             "",
#             "[chorus]",
#             i'll tele my lice, like lolrdan",
#             "pood aid ros, do doob, cannelly with mame",
#               "she
#  a like what's night it",
#             "wendills egath my frow",
#             "to itepoch 15
# Epoch 1/1
# 16501/16501 [==============================] - 57s 3ms/step - loss: 0.4371
# --- Generating with seed: "fire",
#             "no, we didn't light it, but we tried to "
# ------ temperature: 0.2
# fire",
#             "no, we didn't light it, but we tried to fight it",
#             "",
#             "[pre-chorus]",
#             "",
#             "[chorus]",
#             "",
#             "[chorus]",
#             "",
#             "[verse onca ling don't now me",
#             "and tours a good",
#             "",
#             "[chorus]",
#             "and peappe rous goodbut she's no the flole the round",
#             "and he's babyoursean",
#             "",
#             ------ temperature: 0.5
#         "and he's babyoursean",
#             "",
#             "[pre-c-horus]",
#             "i'm gonna ride 'til i can't no more",
#             "i jus ,             "thand don't ether achy",
#             "she'll be a bed",
#             "i'm gonna tike to bues",
#             "a lign go not the world",
#             "and pood bless to fight it a beel from ving i and",
#             "",
#             "[bridge]",
#             "",
#             "[verse onca ling",
#             ------ temperature: 1.0
#             "",
#             "[verse onca ling",
#             "no when't we do long",
#             "",
#             "[bridge]",
#             "and eer dreake don't cort",
#             "that we didn't tack",
#             "",
#             "[verse 2]",
#             "le(re nounge to the round",
#             "",
#             "[pre-c-herie hay here",
#             "aw, ba2by suy ofech, for a whear one",
#             "on like thus hee hood ofame, mandown thise i thuor",
#        ------ temperature: 1.2
# on like thus hee hood ofame, mandown thise i thuor",
#             "i've been when i'm good",
#             "",
#             "[chorus]",
#             "a whon le no jooni", s          "",
#             "[bridge]",
#             "i juit pund for your link",
#             "and tos move aghtursin' sher i man sy do whone",
#             "ens up froming the one",
#             "gello",
#             "swe puidne a near ollufore bawh to lite from",
#             "that only drick, be epoch 16
# Epoch 1/1
# 16501/16501 [==============================] - 54s 3ms/step - loss: 0.4154
# --- Generating with seed: "e only one?",
#             "i've been away for so long",
#     "
# ------ temperature: 0.2
# e only one?",
#             "i've been away for so long",
#             "i'm a biggin' shut the know to mate",
#             "",
#             "[chorus 1]",
#             "hey little sister, she oneam a dreake the world's been turning sintt the world's been turning since this world",
#             "hey little sister, she oneam a dreake the world's been turning sintt the world's been turning since this world",
#             "i'm the paity gloss",
#             "i'm a biggi------ temperature: 0.5
#
#             "i'm the paity gloss",
#             "i'm a bigging sintt this world",
#             "she walk the dool for a wheee breaking you well me way",
#             "i've been whinks enk rom my wording on",
#             "and i sinner call me meaw",
#             "hey like i bles liken' heart",
#             "but macright is a said",
#             "we talken sante the world's been turning sinte the world's been turning sintt the world",
#             "and is harco to------ temperature: 1.0
#  been turning sintt the world",
#             "and is harco to thie willis hever werle ",
#             "[verse 1]",
#             "",
#             "[pre-chorus ly sidn't like jus ghad, dide",
#             "i've been when ike !t a start yoved a the're",
#             "well reaving alr all my old at, cake you was dom",
#             "",
#             "[chorus, gudnill hackstidgote the horse fol",
#             "indwle wead in oce",
#             "i'm gonna rian an thieding f------ temperature: 1.2
# dwle wead in oce",
#             "i'm gonna rian an thieding fies this wiro whonold pearting thiedoving ",
#             "[(horch loke the 'se a res all",
#             "yeshick haaby can'a slike andrfilkit's croth teodd fils"just rupto alwh\",
#             ",     "title": "billy jueljur vinsieve, i's lownestla,",
#             "my heaveris manninia guy headsing you",
#             "no my heathis not moneaw tredw",
#             "",
#             "[bridge]",
#             epoch 17
# Epoch 1/1
# 16501/16501 [==============================] - 53s 3ms/step - loss: 0.3944
# --- Generating with seed: ", but we tried to fight it",
#             "we didn't start th"
# ------ temperature: 0.2
# , but we tried to fight it",
#             "we didn't start the fire",
#             "you can't the bad goom",
#             "you can't the one my blon my heart",
#             "hey little sister, sher sill me andy time",
#             "i'm gonna take my horse to wams",
#             "and i con't tell my firt",
#             "you can't the our i love to thin whit way you town this whow",
#             "",
#             "[pre-chorus]",
#             "i'm gonna take my horse to------ temperature: 0.5
#      "[pre-chorus]",
#             "i'm gonna take my horse to wams",
#             "you can't never eyes",
#             "lef your and a bigppport the old toon",
#             "you can't the hore no hear i'me tell my widcires",
#             "i'm gonna take my horse to was own on the firm",
#             "you can't the one my browd on this world",
#             "i'm ghey buli high lone",
#             "you can't the one my blon you",
#             "you can't the firg",
#    ------ temperature: 1.0
#  the one my blon you",
#             "you can't the firg",
#             "but the bod greal fire the round ande the blow my heart, my achy break",
#             "",
#             "[pre-chorus]",
#             "i must pundarser",
#             "i wall the esouse seep of sooploued i can's lyrics",
#             "i'm gonna take my horse ti the cancely lage 'teln my hibles and spricknt you",
#             "and you're you dien drey",
#             "stapty canste staubing hightys------ temperature: 1.2
#  you dien drey",
#             "stapty canste staubing hightysing youm on the reund you're the ysuckstarn",
#             "we drowd the horses a tam",
#             "len she coniw the blow my ournown",
#             "yes, i'm gonn, night why's do 'i)",
#             "chend all liggy clom fe tom thee-nom",
#             "and enkered llye",
#             "",
#             "[pre-chorus]",
#             "hey little sistling, stur prickto mat lefei those rown meaf thiligirot",
#  epoch 18
# Epoch 1/1
# 16501/16501 [==============================] - 55s 3ms/step - loss: 0.3858
# --- Generating with seed: "ight and your mind is not your own",
#             "lonely is "
# ------ temperature: 0.2
# ight and your mind is not your own",
#             "lonely is the night"
#       ]
#     ],
#     "title": "billig ellinotinighat my heart loner and at you worl whour oll",
#             "",
#             "[pre-chorus]",
#             "she'll staling all this man",
#             "",
#             "[verse 1]",
#             "she'll greame wart white of whot you donety withink hight it a my blow",
#             "",
#             "[pre-chorus]",
#             "she'll stalich the will ------ temperature: 0.5
#        "[pre-chorus]",
#             "she'll stalich the will diy i bod glays",
#             "",
#             "[pre-chorus]",
#             "she'll pread a bay",
#             "she'll be a girl you to i'm no me?",
#             "i'm a brot me, crortand day",
#             "we didn't start the one moued on the fire",
#             "she wall the door da a wars",
#             "but the kicr r the mowty heart to bes goodble gist to line",
#             "sbed is boen in thi kid ------ temperature: 1.0
# goodble gist to line",
#             "sbed is boen in thi kid i'' like this will ducning sunnerm \"rilnightistronigh",
#             "",
#             "[verse u]",
#             "no, start spees mechore \",
#             "ward roun ever is nopmy and fester, mored ald petine mingg",
#             "we kney me winn, wat me her so tom har awn",
#             "for farring ecer it's tell yuurnown on worsing you weeerius hrogh",
#             "he goun i proucking your owing i ro------ temperature: 1.2
# ius hrogh",
#             "he goun i proucking your owing i rownno",
#             "my wears got a rle, do, caros, rancli",
#             "but tocs me, llow!, and foronir (sunders with the ]",
#             "oaly the pound stapima crown",
#             "that's so sudly carsould douni rool",
#             "on a bidn now in the blow",
#             "bad our gold on baby in ad chen like fo mation",
#             "ty i'm heer poudich cor all we dould can't no, socnongs from",epoch 19
# Epoch 1/1
# 16501/16501 [==============================] - 54s 3ms/step - loss: 0.3712
# --- Generating with seed: "hings will kill me yet\"",
#             "",
#             "[cho"
# ------ temperature: 0.2
# hings will kill me yet\"",
#             "",
#             "[chorus]",
#                "she'll see't no oner this with the frooce to the olean",
#             "i'm gonna sinepernelk with me world",
#             "she'll gream berous can't no more",
#             "i'm gonna take my horse to the oleak or the fros good",
#             "i could lie, say i like it like that, i mught at my heart",
#             "i'm gonna take my horse to the oleak or the frold",
#             "------ temperature: 0.5
# onna take my horse to the oleak or the frold",
#             "i'm gonna sinepernelk ar the roun lone",
#             "she'll gream berous cone",
#             "she wall you was a wheee of souss and gross",
#             "i lome so have it like that, i beel",
#             "i'm no good bold in that",
#             "she's so i wime",
#             "i'm gonna take my horse to the oleaky heart",
#             "i could lie, say i like it like that, i miggtown rour old",
#       ------ temperature: 1.0
# d lie, say i like it like that, i miggtown rour old",
#             "we ball you dawithes well brought"
#       ]
#     ],
#     "title":j"biblb g olien – but my her the cars un oon",
#             "billie jean is no mome",
#             "she'll head to figgptrit, matord to",
#             "i’d lofs fice",
#             "my wetly it light]",
#             "",
#             "[verses3]",
#             "ael you can tell my frow to waik the blow \"thi caowh well",
#             "shej------ temperature: 1.2
# y frow to waik the blow \"thi caowh well",
#             "shejl wrack hin so, no-non chms fanger an this world",
#             "uptown x dould like fou food no[b ligeainir",
#             "fillin gros toute",
#                "i'm not my novers ug]",
#                "an't but i krethin's che'r scale, me my proncky"
#
#      "sing us when ne\w me – i cougd",
#             "",
#             "[verse 1]",
#             "fill ights crty hoom now",
#             "and be carepoch 20
# Epoch 1/1
# 16501/16501 [==============================] - 52s 3ms/step - loss: 0.3601
# --- Generating with seed: "show you now, baby, it can happen to you",
#             "",
#  "
# ------ temperature: 0.2
# show you now, baby, it can happen to you",
#             "",
#             "[chorus]",
#             "she'll so sight blow up and like me horse to the one (on bare",
#             "",
#             "[chorus]",
#             "she'll so take my horse to fight it",
#             "she'll so take my horse to fight it",
#             "",
#             "[chorus]",
#             "she'll so fightrus can",
#             "and when i'm gonn",
#             "and i wamb the maght weart lone",
# ------ temperature: 0.5
# n i'm gonn",
#             "and i wamb the maght weart lone",
#             "i wain, dream warn the world's been turning",
#             "",
#             "[chorus]",
#             "she'll seen lyrics | genius lyrics"
# }
# {
#     "lyrics": [
#         [
#             "[verse 1]",
#             "she'll so fightrus can",
#             "i'm the bad guy",
#             "and i sourd go",
#             "and i soon't can't now the one",
#             "",
#             "[verse 1]",
#            ------ temperature: 1.0
# e one",
#             "",
#             "[verse 1]",
#             "she'll so beda sarcame"n"
#             "[ispe]",
#             "but i (ooc",
#             "she'll sre did your gine",
#             ":         "[chorus]",
#             "lonely is the night"
#       ]
#     ]
#     ],
#     "title": "lillighrowhinh esve ae the old to baga",
#             "you'll go courd lin sinto",
#             "",
#             "[verse 1]",
#             "she'll sinne tous gorow",
#             "we di------ temperature: 1.2
# ",
#             "she'll sinne tous gorow",
#             "we didd tlee on byes",
#             "ar there is a sroud the flon-d me wo",
#             "but viggthed house the caring allucs lyrics frartmd, me enothmen'rd ar",
#             "",
#             "[verse 3]",
#             "and on yrust and divs wyrlin' ynowr",
#             "",
#             "[chorus]",
#             "south to le, heeb for peares",
#             "she'll scan't ne, mise pay",
#             "and when ohe epoch 21
# Epoch 1/1
# 16501/16501 [==============================] - 54s 3ms/step - loss: 0.3536
# --- Generating with seed: "     "and if you tell my heart, my achy breaky heart",
#      "
# ------ temperature: 0.2
#      "and if you tell my heart, my achy breaky heart",
#             "she sall a son, that you'd good",
#             "she sall and i lout sood",
#             "she sall the roond it when your floomy heart",
#             "",
#             "[verse 1]",
#             "she wall day your and all by have",
#             "she sall a son, that you'd good at bud",
#             "and i soo son, hee your don, whow",
#             "she wall day your for you?",
#             "no, we did------ temperature: 0.5
#        "she wall day your for you?",
#             "no, we didn't start the fire",
#             "you can't the now the owe mer do",
#             "she's sou punes that i was have",
#             "",
#             "[verse 1]",
#             "she sard a sbees my heart, my achy breaky heart",
#             "i'm no nogo mine",
#             "got dom car ones",
#             "we didn't start the fire",
#             "like it with you're not so the one",
#             "we didn't sta------ temperature: 1.0
# e it with you're not so the one",
#             "we didn't start the floob one",
#             "she sald your don, whith on",
#             "she's soee they hight baby sonewanner you nown,          "un is non hy bed knyow",
#             "don't tall and a dingog, goodle",
#             "an bor fur to freaw you quito drean",
#             "she sart a gon't take my her print",
#             "but she never pown like hous oorlets",
#             "to ses me onepher",
#          ------ temperature: 1.2
# ke hous oorlets",
#             "to ses me onepher",
#             "pcall furon't stawt nety illo so thien up cofe",
#             "darty faure",
#             "i'm beea lights all me your dweaker heart ton'r ocmy one you",
#             "hero's beet an, heary ton",
#             "i'll ou foe ofes drean",
#             "he nightlics lance da",
#             "lyrics | genius lyrics"
# }
# {       "like my ir abyoull like in the ryunn",
#             "le-a la tas day",
#           epoch 22
# Epoch 1/1
# 16501/16501 [==============================] - 55s 3ms/step - loss: 0.3521
# --- Generating with seed: "s – waltz for debby lyrics | genius lyrics"
# }
# {
#     "lyrics""
# ------ temperature: 0.2
# s – waltz for debby lyrics | genius lyrics"
# }
# {
#     "lyrics": [
#         [
#             "[verse 1]",
#             "she's sound one men with me one onea thee's been",
#             "she's sound be awn like this gord",
#             "i'm gonna take my horse to the one onea theee",
#             "[verse 1]",
#             "she's so inspean, shal the horse to the one (on baby",
#             "she's sound plean lyrics | genius lyrics"
# }
# {
#     "lyrics": [
#         [
#          ------ temperature: 0.5
# ics | genius lyrics"
# }
# {
#     "lyrics": [
#         [
#             "[verse 1]",
#             "she's no hevers cown rowns one",
#             "but is goud in so now to foow",
#             "she's sonever realing",
#             "i lon't be an",          "she wale and the fire",
#             "she's so, i know to price that so puckn't tell my heart lone",
#             "to sead ton is not my lover can't no oo",
#             "i'm gonna take my hors to figh",
#             "tha------ temperature: 1.0
#           "i'm gonna take my hors to figh",
#             "thayque your dow it such wnow",
#             "crey bad guy",
#             "knever ese]",
#             "she's soung oneam from buy keall",
#             "makn my heart up for airld",
#             "",
#             "[verse 1]",
#             "fron's and peapifer trust what so theever fortung",
#             "it's a hire ton know",
#             "you gowd dan's no one m",
#             "but god bud",
#             "",
#   ------ temperature: 1.2
# n's no one m",
#             "but god bud",
#             "",
#             "[rust ke thit oreave been whike mus a whepeer to mese",
#             "tharowang your oceane' life to duicen'ie house",
#             "my weart, donew, is one fealy is alwaw",
#             "ta buty dricks quptorsto the one",
#             "",
#             "baly is pout the blowm with ed her bleys ko ether (oonns",
#             "billeby eoving you lit my ton to yourser",
#             "nown ridn't epoch 23
# Epoch 1/1
# 16501/16501 [==============================] - 54s 3ms/step - loss: 0.3353
# --- Generating with seed: "    "it was always burning since the world's been turning",
# "
# ------ temperature: 0.2
#     "it was always burning since the world's been turning",
#             "but ma rean erer on the firm",
#             "i'm the dound good diy",
#             "i'm the dound been witc the one me",
#             "",
#             "[verse 1]",
#             "i'm gonna take my horse to the old town road",
#             "",
#             "[chorus]",
#             "she's nove nearling on liken lett will dinting",
#             "",
#             "[chorus]",
#             "she's so ink------ temperature: 0.5
#        "",
#             "[chorus]",
#             "she's so ink com hor solly?",
#             "i'm gonna take my horse to the old town road",
#             "carot dancice go for fakights the world's beenetwm",
#             "and a can't be will dancer",
#             "spund ron like g your own",
#             "i'm gonna take my horse to the old town",
#             "",
#             "[verse 1]",
#             "you can tell my facm",
#             "i'm the dound give you wot a------ temperature: 1.0
# can tell my facm",
#             "i'm the dound give you wot a whoupsoles alleaddand",
#             "is not she's suching you",
#             "but i bod the floll that wimpthin'",
#             "i could lien no, starser",
# ...
#             "you got a beda't no oreand the day",
#             "",
#             "[ve------ temperature: 1.0
#  beda't no oreand the day",
#             "",
#             "[verse when whe house you dream nearlscgh",
#             "fallin' sand aller tlefaking",
#             "you can to getce anes sead and and give you was down't ?"it this high",
#             "",
#             "[chorus]",
#             "she'll sunday her upperyou",
#             "to sead ton phight what i'm heart",
#             "just we do ne laer sill my fron",
#             "you got a bedy ull tood ra, it awan, be------ temperature: 1.2
#  fron",
#             "you got a bedy ull tood ra, it awan, bedand",
#             "",
#             "[verse 1]",
#             "i lot klout go fort the fire",
#             "like your from tricks quite of paiky my horse",
#             "i wall day a mell my froomy start the fire",
#             "it wat heal he give you daill my hoakors hight it youor",
#             "i'm the bad guy",
#             "oold don't evert agan?",
#             "my weart tond rapper",
#             "epoch 53
# Epoch 1/1
# 16501/16501 [==============================] - 53s 3ms/step - loss: 0.2141
# --- Generating with seed: "dreaming",
#             "i was only dreaming",
#             "i"
# ------ temperature: 0.2
# dreaming",
#             "i was only dreaming",
#             "i'm gonna take my horse to the old town road",
#             "that's got his own",
#             "",
#             "[chorus]",
#             "she'll seep one from herls",
#             "",
#             "[chorus]",
#             "she'll sund",
#             "",
#             "[chorus]",
#             "she'll staling you for you from herl",
#             "and if you tell my heart, downy",
#             "",
#             "[ch------ temperature: 0.5
#  you tell my heart, downy",
#             "",
#             "[chorus]",
#             "she'll stalicot sinted athmuse, a down've heavy heart chen the we like it like that",
#             "he didn ay so your oneth be your day you don't no jeel",
#             "",
#             "[verse 1]",
#             "it was always burning sunderse, the widning i the frome\",
#             "and if you tell my heart, down(se day",
#             "and if you to phine",
#             "",
#       ------ temperature: 1.0
# ",
#             "and if you to phine",
#             "",
#             "[chorus]",
#             "i'm the don't car't no jeam",
#             "and a you don't tell my from vick, lone",
#             "as the suilin' your oneth world",
#             "that's got his own",
#             "when she was a drars that say those on this the round",
#             "",
#             "[pre-chorus]",
#             "and be chear to fightlifortan, sold toom",
#             "",
#             "[vers------ temperature: 1.2
# ightlifortan, sold toom",
#             "",
#             "[verse ,
#             "mme was a swo don't even lanivind firt",
#             "she wall dayrles, down me",
#             "i'y got a lack it an",
#             "carunebre like to the old town road ond whind girl",
#            "and app repp eloama bear",
#             "",
#             "[chorus]",
#             "slapiforne pauckbam wers that's quat rowm",
#             "i'm gonna take my hovs o vinking beer",
#           epoch 54
# Epoch 1/1
# 16501/16501 [==============================] - 53s 3ms/step - loss: 0.2075
# --- Generating with seed: ",
#             "",
#             "[bridge]",
#             "(seye"
# ------ temperature: 0.2
# ,
#             "",
#             "[bridge]",
#             "(seye no go like that, like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like i------ temperature: 0.5
# ke it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like it like that, like it like it like it like it like it like it ride,",
#             "and he's qupind her dream not my son, morad",
#             "",
#             "[verse 1s lin' listel guy",
#             "[verse 1]",
#             "she wall day to fight whind the dires thinkwhis the round",
#             "in tell my old town road",
#             "------ temperature: 1.0
# ound",
#             "in tell my old town road",
#             "you can you dingepper eavenmed",
#             "just been burnigh lyrics"
# }
# {
#     "lyrics": [
#           [
#             "[verse 1]",
#             "to it a can't tell me not",
#             "but now the lovers to back",
#             "in the said, don't thise",
#             "",
#             "[chorus]",
#             "she's beene one mink swe weathe lead",
#             "band the dree sisters a chin' you trees all------ temperature: 1.2
# d",
#             "band the dree sisters a chin' you trees all",
#             "when i wart no",
#             "ben't tall hepe i'll fell",
#             "soupe curperuse wat gis a ding",
#             "no, we didn't light it, buopagp and the hort the one me baby this hove qupt it",
#             "you dance oneam no god, "
#  u! m monigotce, artarter, so pigy days to mugo",
#             "i ]in't bubling you trettle that have the wirles a was old rown wrind fr knet\",
#    epoch 55
# Epoch 1/1
# 16501/16501 [==============================] - 53s 3ms/step - loss: 0.2038
# --- Generating with seed: "loor",
#             "or you can tell my lips to tell my finge"
# ------ temperature: 0.2
# loor",
#             "or you can tell my lips to tell my finges that i wadnidine all",
#             "and if you tell my heart",
#             "i'm the never heal the wimn, i thit will day",
#             "",
#             "[chorus 1es sing up own lle",
#             "ingo fail i  and give my firget and sunply mun",
#             "i'm the never heal the world's been turning on",
#             "i'm the nic-, i can't now trime that i'm ne gill my leaken is not my lone",
#    ------ temperature: 0.5
# 't now trime that i'm ne gill my leaken is not my lone",
#             "somewhern i bed'ven she weeping ore",
#             "i'm the never heal the world's been turning i",
#             "and he's quich o and i",
#             "you he sundaen seepine",
#             "",
#             "[pre-bronny llay rive, i'llorea, cartun",
#             "and he's quich o and the marturning shave the me (hee-heer (ondlie, you the martay",
#             "i just don't think he'd understan------ temperature: 1.0
#  the martay",
#             "i just don't think he'd understand weat",
#             "i'm be town rovind o, i dacking alr hat i've never fall",
#             "thers ave graven lane",
#             "worl the babach",
#             "but god bless the child that iun",
#             "",
#             "[chorus 1nia sinto to",
#             "ip percings so tell my firk",
#             "he give the maghig, id at back",
#             "",
#             "[verse 1]",
#             "she sada------ temperature: 1.2
#           "",
#             "[verse 1]",
#             "she sada no honger can'me theej ming an",
#             "i'm a  firt yourse no jome me mown rood",
#             "on a bed",
#             "that a say nothin' lihat the one gonn",
#             "i'm the one no-ge",
#             "we aid goodbod",
#             "thiske say 'ha (hood on your downiat, me nowh",
#             "facking o , ohe real",
#             "",
#             "owa best we puyw\",
#             "i'm no wh thepoch 56
# Epoch 1/1
# 16501/16501 [==============================] - 53s 3ms/step - loss: 0.2049
# --- Generating with seed: "     "",
#             "[chorus]",
#             "no fair (no fa"
# ------ temperature: 0.2
#      "",
#             "[chorus]",
#             "no fair (no farring",
#             "",
#             "[bridge]",
#             "stas mone, just a giob they horse to the old town road",
#             "",
#             "[bridge]",
#             "stas mone, don't the one me blayser, cand",
#             "he might blow up and kill this mad",
#             "",
#             "[bridge]",
#             "steope my horse to the old town road",
#             "",
#             "[bridge]",
#    ------ temperature: 0.5
#  old town road",
#             "",
#             "[bridge]",
#             "steen mun stron she down, don't even lan,, yab down this high",
#             "",
#             "[bridge]",
#             "steope my horse to the old town road",
#             "",
#             "[bridge]",
#             "stoodp and good at bond ton",
#             "and people are crazy"
# }
# {
#     "lyrics"
# }
# {
#     "lyrics"
# }
# {
#     "lyrics"
# }
# {
#     "lyrics"
# }
# {
#     "lyrics": [
#       [
#             "[verse ------ temperature: 1.0
#    "lyrics"
# }
# {
#     "lyrics": [
#       [
#             "[verse 1]",
#             "hean she eyes",
#             "he leacks robmamand a sack, cantay",
#             "and in'o necer so picning of hing this high",
#             "brien burn bestret your since the world's been turning",
#             "end is gloss the wirn",
#             "jbllody hight ught the one froad on, been",
#             "",
#             "[bridge]",
#             "i'm  one feole my horse to the old town ------ temperature: 1.2
# dge]",
#             "i'm  one feole my horse to the old town road",
#             "",
#             "[bridge]",
#             "stroke my thon clifhe from the froo back",
#             " i’d lie, canie this world",
#             "a say hat nobor is nothe",
#             "",
#             "[verse 1]",
#             "hey wice i gon't kne, dand give",
#             "you pund don't neverter have, babher storn my firm",
#             "she sawn do lours in a that",
#             "",
#   epoch 57
# Epoch 1/1
# 16501/16501 [==============================] - 53s 3ms/step - loss: 0.2043
# --- Generating with seed: "  "gloomy sunday"
#         ]
#     ],
#     "title": "billie holi"
# ------ temperature: 0.2
#   "gloomy sunday"
#         ]
#     ],
#     "title": "billie holigg",
#           "[verse 1]",
#           "stoodbusights and and plowforide",
#             "you can't the bad tylins son,",
#             "you can tell your my heart lyrics | genius lyrics"
# }
# {
#     "lyrics": [
#         [
#             "[verse 1]",
#              "you can tell your my heart lone",
#             "i just don't think this horse that i mood no groke",
#             "",
#             "[chorus]",
#         ------ temperature: 0.5
#  no groke",
#             "",
#             "[chorus]",
#             "so it stroke me, nown-heag",
#             "so hake they winn dream now",
#             "i'm gonna take my horse to the old town road",
#             "but god bless the child that's got his own",
#             "",
#             "[chorus]",
#             "so hake me, \"ler knep you",
#             "i've beene we didnet tue my hever care",
#             "my heavy heart lone",
#             "",
#             "[brid------ temperature: 1.0
#    "my heavy heart lone",
#             "",
#             "[bridge]",
#             "so have on you's be your and the olime the down",
#             "but 's conn's got strange these on the phong",
#             "arl the doldsay, read lyyurnia starking this h",
#             "you can't tell tell me nothid",
#             "he glosse go loupper paice, carp no me reans",
#             "in the said, dreamel",
#             "carle then whilisin' on branking on",
#             "you ------ temperature: 1.2
#     "carle then whilisin' on branking on",
#             "you cartocke that thiss and puye",
#             "but she ever have, i leyving you wathild isan, fron baby from quite , shove the body it a my blone",
#             " uptown the moht ones the lonel yoh",
#             "he mightarbe y i jeee it you veve withis gown",
#             "",
#             "[chorus]",
#             "",
#             "[verse 2]",
#             "",
#             "plics",
#             "",
#          epoch 58
# Epoch 1/1
# 16501/16501 [==============================] - 53s 3ms/step - loss: 0.2020
# --- Generating with seed: "nd if you tell my heart, my achy breaky heart",
#             "
# ------ temperature: 0.2
# nd if you tell my heart, my achy breaky heart",
#             "",
#             "[chorus]",
#             "she'll stalice glackont",
#             "that's got his own",
#             "",
#             "[chorus]",
#             "she'll greal the dove",
#             "hey little sister, shanger is pros",
#             "",
#             "[chorus]",
#             "she'll stalice glacsod",
#             "and i shoure you don't talw tooman",
#             "",
#             "[verse 2]",
#    ------ temperature: 0.5
# t talw tooman",
#             "",
#             "[verse 2]",
#             "she wall days to for awave be to leaven ways",
#             "and hat strange frust the from the one (ond",
#             "i'm the night whike tho facking of your pone",
#             "i'm the night what he prounder",
#             "",
#             "[chorus]",
#             "she'll a says ton'm good at drinkin' me alwe leakore",
#             "",
#             "[chorus]",
#             "speed on breaking------ temperature: 1.0
#   "",
#             "[chorus]",
#             "speed on breaking on you",
#             "i'm tbillien oh, i ben't the wight wtart",
#             "she'll pretayoe",
#             "fallin' into your ocean eyes",
#             "but shake ma scanto for the round i  ouling, bueaving",
#             "",
#             "[chorus]",
#             "now just bones beensing you own",
#             "gren is gonn, so pgone",
#             "don't talk a mell werling you way",
#             "aw,------ temperature: 1.2
#        "don't talk a mell werling you way",
#             "aw, but seep fell craus",
#             "i’d loke a me leaver't sheken lone",
#             "she say",
#             "well rought up oyn",
#             "and what a we didn't like that, like it like thme",
#             "",
#             "thare (hen shell preame and a backoh",
#             "",
#             "[chorus]",
#             "she'll lyfelling sunderstend",
#             "",
#             "[pre-chorus]",
#          epoch 59
# Epoch 1/1
# 16501/16501 [==============================] - 53s 3ms/step - loss: 0.1965
# --- Generating with seed: " tell my heart, my achy breaky heart",
#             "i just d"
# ------ temperature: 0.2
#  tell my heart, my achy breaky heart",
#             "i just don't think he'd understand",
#             "i've never palifur got his own",
#             "i'm the no storbe",
#             "you know that so puysing on your dance",
#             "",
#             "[pre-chorus]",
#             "she'll prowd on bon to fore",
#             "stell and asfor dance pricksprot mus",
#             "i'm the no sty filk",
#             "i'm the pune, don't the world's the world's been tu------ temperature: 0.5
#         "i'm the pune, don't the world's the world's been turning",
#             "that's what she's scang alone",
#             "she'll prowd on andan, sas, the wer uy her dance you leamew",
#             "i'm the lovers and foo you to proy the round",
#             "in the dance thes word for a whold",
#             "i'm thit's what i sould so e oh bom",
#             "i got his gross",
#             "we didn't start the fire",
#             "it was always burning since------ temperature: 1.0
# 't start the fire",
#             "it was always burning since the world's been turning",
#             "i pouckit so in this horse that i widlwaky knows",
#             "and people ale day",
#             "i poull me 'nost ve, call the floor, thame my heavy 'san, saidieants firs",
#             "down, strange frust that it we tried to fight the word",
#             "",
#             "[chorus]",
#             "she'll gream ar the one mane",
#             "uld lone, weand an------ temperature: 1.2
# e'll gream ar the one mane",
#             "uld lone, weand and a mantr prowdy",
#             "you pun onever hylich,
#             "tharos",
#             "then one deaty leave the world's thot, duptver reay from was heart",
#             "i'm thickornd frosbton ingarinia stars",
#             "but i wads she pring a scald",
#             "then one 'me goce",
#             "a buding's burning ohother scin)",
#             "i'm a can't tell my heart, my achy brenking firo"CPU times: user 4h 8min 37s, sys: 53min 58s, total: 5h 2min 35s
# Wall time: 1h 32min 21s

# %%
model.save('billie3_128_60epochs.h5')
